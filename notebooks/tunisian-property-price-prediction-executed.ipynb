# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

import warnings
warnings.filterwarnings(action='ignore')

# %%
data = pd.read_csv('../data/csv/Property Prices in Tunisia.csv')
data2 = pd.read_csv('../data/csv/centralized_listings.csv')

# %%
data
# Out:
#                     category  room_count  bathroom_count   size      type  \
# 0         Terrains et Fermes        -1.0            -1.0   -1.0  À Vendre
# 1         Terrains et Fermes        -1.0            -1.0   -1.0  À Vendre
# 2               Appartements         2.0             1.0   80.0   À Louer
# 3      Locations de vacances         1.0             1.0   90.0   À Louer
# 4               Appartements         2.0             2.0  113.0  À Vendre
# ...                      ...         ...             ...    ...       ...
# 12743     Terrains et Fermes        -1.0            -1.0   -1.0  À Vendre
# 12744           Appartements         1.0             1.0  100.0   À Louer
# 12745      Maisons et Villas         3.0             1.0  760.0  À Vendre
# 12746      Maisons et Villas         3.0             1.0  190.0  À Vendre
# 12747      Maisons et Villas         2.0             1.0   70.0   À Louer
#
#            price    city         region  log_price
# 0       100000.0  Ariana         Raoued   5.000000
# 1       316000.0  Ariana  Autres villes   5.499687
# 2          380.0  Ariana  Autres villes   2.579784
# 3           70.0  Ariana  Autres villes   1.845098
# 4       170000.0  Ariana   Ariana Ville   5.230449
# ...          ...     ...            ...        ...
# 12743  3200000.0   Tunis  Sidi Bou Said   6.505150
# 12744      600.0   Tunis  Autres villes   2.778151
# 12745  1950000.0   Tunis       La Marsa   6.290035
# 12746   240000.0   Tunis       La Marsa   5.380211
# 12747      500.0   Tunis  Sidi Bou Said   2.698970
#
# [12748 rows x 9 columns]

# %%
data2
# Out:
#                                      record_id    source  \
# 0     b52c131b14c34676e0514f5aacd01ab4e7496631    Tayara
# 1     f05bede211d8383931fe864870751bd298364d88    Tayara
# 2     e0e43d1822dc1c8f31ffb91f8ac0e9fc172207ac    Tayara
# 3     9f3329d4243fd38fc3f224a7d53f927e728907fc    Tayara
# 4     6cfe88d69e7987cc3ae3fb02c6352b9b6515bce7    Tayara
# ...                                        ...       ...
# 2818  eb52d7246cafbccca3c1123b439c427c797a3bf3  Bigdatis
# 2819  6584962e8b358890011bd95efeede320b5829b56  Bigdatis
# 2820  5dce9b72b7078ab871c45b1f2adacdab0fad600b  Bigdatis
# 2821  ff02d84d082571e1bd49dc283232abf27837f5f2  Bigdatis
# 2822  d058a3dd57cc70db8365ef5f990ef8694a65dce6  Bigdatis
#
#                  source_file  \
# 0       tayara_listings.json
# 1       tayara_listings.json
# 2       tayara_listings.json
# 3       tayara_listings.json
# 4       tayara_listings.json
# ...                      ...
# 2818  bigdatis_listings.json
# 2819  bigdatis_listings.json
# 2820  bigdatis_listings.json
# 2821  bigdatis_listings.json
# 2822  bigdatis_listings.json
#
#                                             listing_url  \
# 0     https://www.tayara.tn/item/appartements/tunis/...
# 1     https://www.tayara.tn/item/appartements/sousse...
# 2     https://www.tayara.tn/item/appartements/tunis/...
# 3     https://www.tayara.tn/item/appartements/ariana...
# 4     https://www.tayara.tn/item/appartements/ben-ar...
# ...                                                 ...
# 2818  https://bigdatis.tn/details/vente/lac-2/appart...
# 2819  https://bigdatis.tn/details/vente/tunis-centre...
# 2820  https://bigdatis.tn/details/vente/le-kram/appa...
# 2821  https://bigdatis.tn/details/vente/el-mourouj-4...
# 2822  https://bigdatis.tn/details/vente/ain-zaghouan...
#
#                                                   title  \
# 0                               studio meublé a laouina
# 1                        S+2 a boukhzar bouhsina Sousse
# 2     à louer appartement studio meublé location par...
# 3                    Location S+1 jardins d'el menzah 2
# 4             A louer un bureau s+2 HST au centre h.lif
# ...                                                 ...
# 2818                  « À vendre Appartement S0 Lac 2 »
# 2819                   « A louer appartement s1 Tunis »
# 2820                            « Appartement S3 Kram »
# 2821         « A vendre un appartement s3 à Mourouj 4 »
# 2822  « Coquet Appartement S+2 Jamais Habité à Ain Z...
#
#                                        description transaction_type  \
# 0                                              NaN              NaN
# 1                                              NaN              NaN
# 2                                              NaN             rent
# 3                                              NaN             rent
# 4                                              NaN             rent
# ...                                            ...              ...
# 2818              Appartement S+0 à vendre à Lac 2             sale
# 2819       Appartement S+1 à vendre à Tunis Centre             rent
# 2820            Appartement S+3 à vendre à Le Kram             sale
# 2821       Appartement S+3 à vendre à El Mourouj 4             sale
# 2822  Appartement S+2 à vendre à Ain Zaghouan Nord             sale
#
#      property_type  price_tnd  surface_m2  ...       neighborhood  \
# 0      Appartement      100.0         NaN  ...                NaN
# 1      Appartement      550.0         NaN  ...                NaN
# 2      Appartement       80.0         NaN  ...                NaN
# 3      Appartement   999999.0         NaN  ...                NaN
# 4      Appartement      850.0         NaN  ...                NaN
# ...            ...        ...         ...  ...                ...
# 2818   Appartement   300000.0        41.0  ...              Lac 2
# 2819   Appartement   150000.0        50.0  ...       Tunis Centre
# 2820   Appartement   360000.0       150.0  ...            Le Kram
# 2821   Appartement   160000.0        80.0  ...       El Mourouj 4
# 2822   Appartement   535000.0       115.0  ...  Ain Zaghouan Nord
#
#                              location_raw  \
# 0                                     100
# 1                                     550
# 2                                      80
# 3                                     999
# 4                                     850
# ...                                   ...
# 2818               Lac 2, La Marsa, Tunis
# 2819        Tunis Centre, Bab Bhar, Tunis
# 2820              Le Kram, Le Kram, Tunis
# 2821  El Mourouj 4, El Mourouj, Ben Arous
# 2822    Ain Zaghouan Nord, Le Kram, Tunis
#
#                           raw_governorate raw_city        posted_at  \
# 0                                     100      NaN              NaN
# 1                                     550      NaN              NaN
# 2                                      80      NaN              NaN
# 3                                     999      NaN              NaN
# 4                                     850      NaN              NaN
# ...                                   ...      ...              ...
# 2818               Lac 2, La Marsa, Tunis      NaN  Il y a 3 heures
# 2819        Tunis Centre, Bab Bhar, Tunis      NaN  Il y a 3 heures
# 2820              Le Kram, Le Kram, Tunis      NaN  Il y a 3 heures
# 2821  El Mourouj 4, El Mourouj, Ben Arous      NaN              NaN
# 2822    Ain Zaghouan Nord, Le Kram, Tunis      NaN  Il y a 4 heures
#
#                             scraped_at page      category  \
# 0     2026-02-15T20:49:58.287440+00:00    1  Appartements
# 1     2026-02-15T20:50:00.474189+00:00    1  Appartements
# 2     2026-02-15T20:50:00.872590+00:00    1  Appartements
# 3     2026-02-15T20:50:01.304151+00:00    1  Appartements
# 4     2026-02-15T20:50:01.672730+00:00    1  Appartements
# ...                                ...  ...           ...
# 2818  2026-02-17T00:38:09.862744+00:00    1           NaN
# 2819  2026-02-17T00:38:09.987652+00:00    1           NaN
# 2820  2026-02-17T00:38:10.213856+00:00    1           NaN
# 2821  2026-02-17T00:38:10.392036+00:00    1           NaN
# 2822  2026-02-17T00:38:10.631195+00:00    1           NaN
#
#                                         meta_title  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 2818              Appartement S+0 à vendre à Lac 2
# 2819       Appartement S+1 à vendre à Tunis Centre
# 2820            Appartement S+3 à vendre à Le Kram
# 2821       Appartement S+3 à vendre à El Mourouj 4
# 2822  Appartement S+2 à vendre à Ain Zaghouan Nord
#
#                                  labels
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 2818               S+0 | 41 m² | Agence
# 2819  S+1 | 50 m² | Agence, Particulier
# 2820              S+3 | 150 m² | Agence
# 2821               S+3 | 80 m² | Agence
# 2822              S+2 | 115 m² | Agence
#
# [2823 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12748 entries, 0 to 12747
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category        12748 non-null  str
#  1   room_count      12748 non-null  float64
#  2   bathroom_count  12748 non-null  float64
#  3   size            12748 non-null  float64
#  4   type            12748 non-null  str
#  5   price           12748 non-null  float64
#  6   city            12748 non-null  str
#  7   region          12748 non-null  str
#  8   log_price       12748 non-null  float64
# dtypes: float64(5), str(4)
# memory usage: 896.5 KB

# %% [markdown]
# # Preprocessing

# %%
def preprocess_inputs(df):
    df = df.copy()
    
    # Encode missing values properly
    df = df.replace(-1, np.nan)
    
    # Fill missing values with column medians
    for column in ['room_count', 'bathroom_count', 'size']:
        df[column] = df[column].fillna(df[column].median())
    
    # Binary encoding
    df['type'] = df['type'].replace({'À Louer': 0, 'À Vendre': 1})
    
    # One-hot encoding
    for column in ['category', 'city', 'region']:
        dummies = pd.get_dummies(df[column], prefix=column)
        df = pd.concat([df, dummies], axis=1)
        df = df.drop(column, axis=1)
    
    # Drop log_price column
    df = df.drop('log_price', axis=1)
    
    # Split df into X and y
    y = df['price']
    X = df.drop('price', axis=1)
    
    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True, random_state=1)
    
    # Scale X
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = pd.DataFrame(scaler.transform(X_train), index=X_train.index, columns=X_train.columns)
    X_test = pd.DataFrame(scaler.transform(X_test), index=X_test.index, columns=X_test.columns)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_inputs(data)

# %%
X_train
# Out:
#        room_count  bathroom_count      size      type  category_Appartements  \
# 83      -0.594847       -0.415569 -0.526100 -1.240965              -0.762766
# 1917    -0.594847        1.004080 -0.377567 -1.240965              -0.762766
# 7857     0.122329       -0.415569 -0.139914 -1.240965              -0.762766
# 5044    -0.594847       -0.415569 -0.377567 -1.240965              -0.762766
# 2726     0.122329       -0.415569 -0.258740 -1.240965               1.311018
# ...           ...             ...       ...       ...                    ...
# 10955   -1.312023       -0.415569 -0.852872  0.805824              -0.762766
# 905     -1.312023       -0.415569 -0.454804 -1.240965               1.311018
# 5192    -0.594847       -0.415569 -0.585513 -1.240965              -0.762766
# 12172    0.122329       -0.415569 -0.377567 -1.240965              -0.762766
# 235      0.122329        1.004080 -0.229034  0.805824               1.311018
#
#        category_Bureaux et Plateaux  category_Colocations  \
# 83                        -0.195968             13.321411
# 1917                      -0.195968             -0.075067
# 7857                      -0.195968             -0.075067
# 5044                       5.102881             -0.075067
# 2726                      -0.195968             -0.075067
# ...                             ...                   ...
# 10955                     -0.195968             -0.075067
# 905                       -0.195968             -0.075067
# 5192                       5.102881             -0.075067
# 12172                     -0.195968             -0.075067
# 235                       -0.195968             -0.075067
#
#        category_Locations de vacances  \
# 83                           -0.15142
# 1917                         -0.15142
# 7857                         -0.15142
# 5044                         -0.15142
# 2726                         -0.15142
# ...                               ...
# 10955                        -0.15142
# 905                          -0.15142
# 5192                         -0.15142
# 12172                        -0.15142
# 235                          -0.15142
#
#        category_Magasins, Commerces et Locaux industriels  \
# 83                                             -0.233407
# 1917                                           -0.233407
# 7857                                           -0.233407
# 5044                                           -0.233407
# 2726                                           -0.233407
# ...                                                  ...
# 10955                                           4.284361
# 905                                            -0.233407
# 5192                                           -0.233407
# 12172                                          -0.233407
# 235                                            -0.233407
#
#        category_Maisons et Villas  ...  region_Tozeur  region_Tunis  \
# 83                      -0.575323  ...      -0.055091     -0.113253
# 1917                     1.738154  ...      -0.055091     -0.113253
# 7857                     1.738154  ...      -0.055091     -0.113253
# 5044                    -0.575323  ...      -0.055091     -0.113253
# 2726                    -0.575323  ...      -0.055091     -0.113253
# ...                           ...  ...            ...           ...
# 10955                   -0.575323  ...      -0.055091     -0.113253
# 905                     -0.575323  ...      -0.055091     -0.113253
# 5192                    -0.575323  ...      -0.055091     -0.113253
# 12172                    1.738154  ...      -0.055091     -0.113253
# 235                     -0.575323  ...      -0.055091     -0.113253
#
#        region_Téboulba  region_Téboursouk  region_Utique  region_Zaghouan  \
# 83           -0.018339          -0.014973       -0.02594        -0.086323
# 1917         -0.018339          -0.014973       -0.02594        -0.086323
# 7857         -0.018339          -0.014973       -0.02594        -0.086323
# 5044         -0.018339          -0.014973       -0.02594        -0.086323
# 2726         -0.018339          -0.014973       -0.02594        -0.086323
# ...                ...                ...            ...              ...
# 10955        -0.018339          -0.014973       -0.02594        -0.086323
# 905          -0.018339          -0.014973       -0.02594        -0.086323
# 5192         -0.018339          -0.014973       -0.02594        -0.086323
# 12172        -0.018339          -0.014973       -0.02594        -0.086323
# 235          -0.018339          -0.014973       -0.02594        -0.086323
#
#        region_Zaouit-Ksibat Thrayett  region_Zarzis  region_Zarzouna  \
# 83                         -0.066256      -0.023678        -0.021177
# 1917                       -0.066256      -0.023678        -0.021177
# 7857                       -0.066256      -0.023678        -0.021177
# 5044                       -0.066256      -0.023678        -0.021177
# 2726                       -0.066256      -0.023678        -0.021177
# ...                              ...            ...              ...
# 10955                      -0.066256      -0.023678        -0.021177
# 905                        -0.066256      -0.023678        -0.021177
# 5192                       -0.066256      -0.023678        -0.021177
# 12172                      -0.066256      -0.023678        -0.021177
# 235                        -0.066256      -0.023678        -0.021177
#
#        region_Zéramdine
# 83            -0.010587
# 1917          -0.010587
# 7857          -0.010587
# 5044          -0.010587
# 2726          -0.010587
# ...                 ...
# 10955         -0.010587
# 905           -0.010587
# 5192          -0.010587
# 12172         -0.010587
# 235           -0.010587
#
# [8923 rows x 292 columns]

# %%
y_train
# Out:
# 83           130.0
# 1917         550.0
# 7857         600.0
# 5044         700.0
# 2726         600.0
#            ...
# 10955    8000000.0
# 905          800.0
# 5192         450.0
# 12172        500.0
# 235       210000.0
# Name: price, Length: 8923, dtype: float64

# %% [markdown]
# # Training

# %%
models = {
    "                     Linear Regression": LinearRegression(),
    " Linear Regression (L2 Regularization)": Ridge(),
    " Linear Regression (L1 Regularization)": Lasso(),
    "                   K-Nearest Neighbors": KNeighborsRegressor(),
    "                        Neural Network": MLPRegressor(),
    "                         Decision Tree": DecisionTreeRegressor(),
    "                         Random Forest": RandomForestRegressor(),
    "                     Gradient Boosting": GradientBoostingRegressor()
}

for name, model in models.items():
    model.fit(X_train, y_train)
    print(name + " trained.")
# Out:
#                      Linear Regression trained.
#  Linear Regression (L2 Regularization) trained.
#  Linear Regression (L1 Regularization) trained.
#                    K-Nearest Neighbors trained.
#                         Neural Network trained.
#                          Decision Tree trained.
#                          Random Forest trained.
#                      Gradient Boosting trained.

# %% [markdown]
# # Results

# %%
for name, model in models.items():
    y_pred = model.predict(X_test)
    rmse = np.sqrt(np.mean((y_test - y_pred)**2))
    print(name + " RMSE: {:.2f}".format(rmse))
# Out:
#                      Linear Regression RMSE: 1618497478.22
#  Linear Regression (L2 Regularization) RMSE: 1618496260.65
#  Linear Regression (L1 Regularization) RMSE: 1618365373.29
#                    K-Nearest Neighbors RMSE: 1641440742.06
#                         Neural Network RMSE: 1617133684.42
#                          Decision Tree RMSE: 1619211526.60
#                          Random Forest RMSE: 1619761980.38
#                      Gradient Boosting RMSE: 1618062067.09

# %%
for name, model in models.items():
    r2 = model.score(X_test, y_test)
    print(name + " R^2: {:.4f}".format(r2))
# Out:
#                      Linear Regression R^2: -0.0020
#  Linear Regression (L2 Regularization) R^2: -0.0020
#  Linear Regression (L1 Regularization) R^2: -0.0018
#                    K-Nearest Neighbors R^2: -0.0306
#                         Neural Network R^2: -0.0003
#                          Decision Tree R^2: -0.0029
#                          Random Forest R^2: -0.0036
#                      Gradient Boosting R^2: -0.0015
